# %% [markdown]
# # Estimation de posture dans une image
#
# Pour ce TP ainsi que le suivant, nous allons traiter le problème de la détection du "squelette" d'un humain dans une image, tel qu'illustré dans la figure ci-dessous.
#
# ![Texte alternatif…](https://drive.google.com/uc?id=1HpyLwzwkFdyQ6APoGZQJL7f837JCHNkh)
#
# Nous allons pour ce faire utiliser le [Leeds Sport Pose Dataset](https://sam.johnson.io/research/lspet.html) qui introduit 10000 images présentant des sportifs dans diverses situations, augmentées d'une annotation manuelle du squelette.
#
# À chaque image est associée une matrice de taille 3x14, correspondant aux coordonnées dans l'image des 14 joints du squelette de la personne décrite dans l'image. La 3e dimension désigne la visibilité du joint (1 s'il est visible, 0 s'il est occulté)
#
# Ces joints sont, dans l'ordre :
# *   Cheville droite
# *   Genou droit
# *   Hanche droite
# *   Hanche gauche
# *   Genou gauche
# *   Cheville gauche
# *   Poignet droit
# *   Coude droit
# *   Épaule droite
# *   Épaule gauche
# *   Coude gauche
# *   Poignet gauche
# *   Cou
# *   Sommet du crâne
#
# Pour un rappel des notions vues en cours sur ce sujet, vous pouvez regarder la vidéo ci-dessous :

# %%
from IPython.display import IFrame
IFrame("https://video.polymny.studio/?v=84ace9c1-f460-4375-9b33-917c3ff82c83/", width=640, height=360)
# Out:
#         <iframe
#             width="640"
#             height="360"
#             src="https://video.polymny.studio/?v=84ace9c1-f460-4375-9b33-917c3ff82c83/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Méthodologie
#
# Pour résoudre ce problème, nous allons suivre une méthodologie similaire à celle présentée dans le 2e cours, et rappelée sur la figure suivante :
#
# ![Méthodologie de développement d'un algorithme d'apprentissage profond](https://drive.google.com/uc?id=195pkcjca4r_g86KDt2LCe0QdQsMC6iba)
#
# Ainsi nous allons commencer par une modélisation simple du problème, construire un modèle et l'améliorer pas à pas et évaluer sa performance.
# Dans un second temps, nous modifierons la modélisation du problème, et donc l'architecture utilisée, afin d'améliorer les résultats.
#
# Pour chacune de ces deux étapes, je vous suggère de suivre la démarche suivante :
#
# - Simplifier le problème en traitant 10 imagettes (par exemple de dimension $64 \times 64$) et construire un réseau qui surapprend parfaitement (qui diminue la perte jusqu'à quasiment 0)
# - Ajouter des images (~1000) et recalibrer le réseau pour à nouveau, obtenir un sur-apprentissage
# - Commencer à corriger le sur-apprentissage en ajoutant de la régularisation
# - Et enfin, utiliser l'ensemble de la base de données pour diminuer le sur-apprentissage au maximum

# %% [markdown]
# # Régression de la position des joints

# %% [markdown]
# Dans un premier temps, et comme vu en cours, nous allons nous inspirer de l'algorithme DeepPose (**[Toshev et al.] DeepPose : Human Pose Estimation via Deep Neural Networks**) et formuler le problème comme une régression de la position (x,y) des joints dans l'espace de l'image.

# %% [markdown]
# Commencez par télécharger la base de données sur Github

# %%
# !git clone https://github.com/axelcarlier/lsp.git
# Out:
# fatal: destination path 'lsp' already exists and is not an empty directory.

# %% [markdown]
# Le bloc suivant contient une fonction qui permet de charger les images de la base de données dans les variables x et y. Par défaut les images sont redimensionnées en taille 128$\times$128 et la base de données contient 1000 images. Pour commencer et vous permettre de travailler plus efficacement, **je vous suggère très fortement de diminuer la dimension des images** (par exemple 64$\times$64) **et de ne travailler que sur un ensemble réduit d'images** (par exemple, 10).
#
#
# N'oubliez pas également de diviser les données en images de test et/ou de validation pour obtenir des informations sur le sur-apprentissage éventuel.

# %%
import numpy as np
import PIL
from PIL import Image
import os, sys
from scipy.io import loadmat

# Cette fonction permettra plus tard de charger plus ou moins d'images (en modifiant le paramètre num_images)
# et de modifier la dimension d'entrée
def load_data(image_size=128, num_images=1000):

  path = "./lsp/images/"
  dirs = sorted(os.listdir(path))

  x = np.zeros((min(num_images,len(dirs)),image_size,image_size,3))
  y = np.zeros((min(num_images,len(dirs)), 3, 14))
    
  #Chargement des joints    
  mat_contents = loadmat('./lsp/joints.mat')
  joints = mat_contents['joints']

  # Chargement des images, qui sont rangées dans lsp/images
  for i in range(min(num_images,len(dirs))):
    item = dirs[i]
    if os.path.isfile(path+item):
        img = Image.open(path+item)
        # Redimensionnement et sauvegarde des joints
        y[i, 0] = joints[:,0,i]*image_size/img.size[0]
        y[i, 1] = joints[:,1,i]*image_size/img.size[1]
        y[i, 2] = joints[:,2,i]
        # Redimensionnement et sauvegarde des images        
        img = img.resize((image_size,image_size))
        x[i] = np.asarray(img)


  return x, y

# Chargement de seulement 10 images, de taille 64x64
x, y = load_data(image_size=64, num_images=1000)      
x.shape, y.shape
# Out:
# ((1000, 64, 64, 3), (1000, 3, 14))

# %%
labels= {0: 'Cheville droite',
         1: 'Genou droit',
         2: 'Hanche droite',
         3: 'Hanche gauche',
         4: 'Genou gauche',
         5: 'Cheville gauche',
         6: 'Poignet droit',
         7: 'Coude droit',
         8: 'Épaule droite',
         9: 'Épaule gauche',
         10: 'Coude gauche',
         11: 'Poignet gauche',
         12: 'Cou',
         13: 'Sommet du crâne'}

# %% [markdown]
# La fonction suivante vous permet de visualiser les données. Vous vous rendrez compte que certaines données sont manquantes ! En effet quand des joints sont occultés dans les images, des valeurs de position aberrantes (négatives) sont indiquées. Dans ce cas, nous n'afficherons pas les articulations.

# %%
import matplotlib.pyplot as plt

# Fonction d'affichage d'une image et de son label associé
def print_data(x,y,i):
    
  if y.shape[1] < 3:
    y_new = np.ones((y.shape[0], 3, y.shape[2]))
    y_new[:,0:2,:] = y
    y = y_new
    
  plt.figure(figsize=(5, 5))
  plt.imshow(x[i]/255)
  for j in range(0,14):
    if y[i, 2, j] == 1:
        plt.scatter(y[i,0,j],y[i,1,j],label=labels.get(j))

  # Jambe droite      
  if (y[i, 2, 0] + y[i, 2, 1] == 2):
      plt.plot(y[i,0,0:2],y[i,1,0:2],'b')
  # Cuisse droite      
  if (y[i, 2, 1] + y[i, 2, 2] == 2):
      plt.plot(y[i,0,1:3],y[i,1,1:3],'b')
  # Bassin     
  if (y[i, 2, 2] + y[i, 2, 3] == 2):
      plt.plot(y[i,0,2:4],y[i,1,2:4],'b')
  # Cuisse gauche      
  if (y[i, 2, 3] + y[i, 2, 4] == 2):
      plt.plot(y[i,0,3:5],y[i,1,3:5],'b')
  # Jambe gauche      
  if (y[i, 2, 4] + y[i, 2, 5] == 2):
      plt.plot(y[i,0,4:6],y[i,1,4:6],'b')
  # Avant-bras droit      
  if (y[i, 2, 6] + y[i, 2, 7] == 2):
      plt.plot(y[i,0,6:8],y[i,1,6:8],'b')
  # Bras droit      
  if (y[i, 2, 7] + y[i, 2, 8] == 2):
      plt.plot(y[i,0,7:9],y[i,1,7:9],'b')
  # Bras gauche     
  if (y[i, 2, 9] + y[i, 2, 10] == 2):
      plt.plot(y[i,0,9:11],y[i,1,9:11],'b')
  # Avant-bras gauche      
  if (y[i, 2, 10] + y[i, 2, 11] == 2):
      plt.plot(y[i,0,10:12],y[i,1,10:12],'b') 
  # Buste droit
  x1=[y[i,0,2],y[i,0,12]]
  y1=[y[i,1,2],y[i,1,12]]
  if (y[i, 2, 2] + y[i, 2, 12] == 2):
      plt.plot(x1, y1,'b')
  # Buste gauche
  x1=[y[i,0,3],y[i,0,12]]
  y1=[y[i,1,3],y[i,1,12]]
  if (y[i, 2, 3] + y[i, 2, 12] == 2):
      plt.plot(x1, y1,'b')
  # Omoplate droite
  x1=[y[i,0,8],y[i,0,12]]
  y1=[y[i,1,8],y[i,1,12]]
  if (y[i, 2, 8] + y[i, 2, 12] == 2):
      plt.plot(x1, y1,'b')
  # Omoplate gauche
  x1=[y[i,0,9],y[i,0,12]]
  y1=[y[i,1,9],y[i,1,12]]
  if (y[i, 2, 9] + y[i, 2, 12] == 2):
      plt.plot(x1, y1,'b')
  # Tete     
  if (y[i, 2, 12] + y[i, 2, 13] == 2):
      plt.plot(y[i,0,12:14],y[i,1,12:14],'b')

  plt.axis([0, x.shape[1], x.shape[2], 0])
  plt.show()
  #plt.legend()

# Affichage aléatoire d'une image
print_data(x,y,np.random.randint(x.shape[0]-1))

# %% [markdown]
# Si nous formulons ce problème comme une régression, nous allons utiliser pour évaluer nos réseaux de neurones l'erreur quadratique moyenne (fonction *MSE*). Cette fonction sera parfaite comme fonction de perte, mais elle ne permet pas d'appréhender les résultats de manière satisfaisante.
#
# Une métrique commune en estimation de posture est le **PCK0.5**, pour *Percentage of Correct Keypoints*. *0.5* correspond à un seuil en-deça duquel on considère qu'un joint est correctement estimé. Cette question du seuil est particulièrement sensible car il faut utiliser une valeur qui soit valable pour n'importe quelle image. La personne considérée peut apparaître plus ou moins largement sur l'image, de face ou de profil, ce qui fait qu'une erreur de prédiction sur un joint peut avoir une importance très grande ou très faible selon les cas.
#
# Pour résoudre cette ambiguïté, on considère dans la métrique du **PCK0.5** que la référence est la taille de la tête, définie par la distance entre le joint du cou et le joint de la tête sur la vérité terrain. Un joint prédit par le réseau sera considéré correct s'il est situé à une distance inférieure à la moitié (*0.5*) de la taille de la tête par rapport au joint réel. ([Andriluka et al.] 2D Human Pose Estimation: New Benchmark and State of the Art Analysis)

# %%
import numpy.matlib 

# Calcul du "Percentage of Correct Keypoint" avec seuil alpha :
# On compte corrects les joints pour lesquels la distance entre valeurs réelle et prédite 
# est inférieure à alpha fois la dimension de la tête (c'est un peu arbitraire...)
# On ne comptera pas les joints invisibles.
# y_true est de dimension Nx3x14 et y_pred Nx2x14 (le réseau ne prédit pas la visibilité)
def compute_PCK_alpha(y_true, y_pred, alpha=0.5):
    # Calcul des seuils ; la taille de la tête est la distance entre joints 12 et 13
    head_sizes = np.sqrt(np.square(y_true[:,0,13]-y_true[:,0,12])+np.square(y_true[:,1,13]-y_true[:,1,12]))
    thresholds = alpha*head_sizes
    thresholds = np.matlib.repmat(np.expand_dims(thresholds, 1), 1, 14)

    # Calcul des distances inter-joints
    joints_distances = np.sqrt(np.square(y_true[:,0,:]-y_pred[:,0,:]) + np.square(y_true[:,1,:]-y_pred[:,1,:]))

    # Visibilité des joints de la vérité terrain
    visibility = y_true[:,2,:]
    
    total_joints = np.count_nonzero(visibility==1)
    correctly_predicted_joints = np.count_nonzero(np.logical_and(joints_distances<thresholds, visibility == 1))
    
    return correctly_predicted_joints/total_joints

# %% [markdown]
# Comme dit précédemment, on va utiliser l'erreur quadratique moyenne (*MSE*) comme fonction de coût pour entraîner notre réseau de neurones, et on peut également comme pour le TP2 utiliser l'erreur absolue moyenne (*MAE*) pour obtenir une estimation plus fine des performances de notre réseau pendant l'entraînement (on obtient une erreur moyenne en pixels, ce qui est plus simple à interpréter).
#
# Il y a cependant une subtilité importante évoquée un peu plus haut : certains joints sont invisibles, et ont des coordonnées négatives (pour, il faut l'avouer, une raison un peu inexplicable). Il est important de ne pas affecter l'apprentissage en faisant prédire ces valeurs négatives, insensées, au réseau.
#
# On doit donc implanter nous-même notre propre fonction de coût, qui ne va pas prendre en compte les joints invisibles. Pour cela, il faut savoir que la vérité-terrain contient en fait 3 valeurs pour chaque joint : les 2 premières sont ses coordonnées sur l'image, la 3e représente la visibilité du joint (1 s'il est visible, 0 sinon).
#
# La fonction *custom_mse*, définie juste en-dessous, réalise cette opération. Prenez le temps de comprendre ce qu'il s'y passe. **Remarque importante** : Ce code fait appel à des fonctions particulières du Backend de Keras, dont vous trouverez les détails sur [cette page](https://keras.rstudio.com/articles/backend.html). Ces fonctions doivent traiter des tenseurs, de type *Tensor* (et pas des tableaux numpy), car elles seront appelées pendant l'entraînement sur des variables internes à Tensorflow. Les fonctions utilisables sont également limitées car il faut pouvoir dériver la fonction *custom_mse* pour la rétropropagation des gradients.

# %%
import keras.backend as K
# y_true : vérité terrain de dimension B x 3 x 14
# y_pred : une prédiction de dimension B x 2 x 14 (on ne prédit pas la visibilité)
# B est le nombre d'images considérées (par exemple, pourra être la taille d'un mini-batch)
def custom_mse(y_true, y_pred):
    # Changement de dimension : Bx3x14 -> Bx14x3
    y_true = K.permute_dimensions(y_true, (0, 2, 1))
    # Changement de dimension : Bx14x3 -> (B*14)x3
    y_true = K.reshape(y_true, shape=(-1, 3))
  
    # Changement de dimension : Bx2x14 -> Bx14x2
    y_pred = K.permute_dimensions(y_pred, (0, 2, 1))
    # Changement de dimension : Bx14x2 -> (B*14)x2
    y_pred = K.reshape(y_pred, shape=(-1, 2))
    
    # Détermination de l'indices des joints visibles
    visible = K.greater_equal(y_true[:, 2], 1)  
    indices = K.arange(0, K.shape(y_true)[0])
    indices_visible = indices[visible]
    
    # Sélection des vérité-terrains et prédictions des joints visibles
    y_true_visible = K.gather(y_true[:,0:2], indices_visible)
    y_pred_visible = K.gather(y_pred, indices_visible)
    
    # Calcul de la MSE
    return K.mean(K.square(y_pred_visible[:,0] - y_true_visible[:,0]) + K.square(y_pred_visible[:,1] - y_true_visible[:,1]))

# %% [markdown]
# Si vous avez bien compris le code de *custom_mse*, vous devriez pouvoir sans trop de problèmes écrire le code pour la fonction *custom_mae* ci-dessous :

# %%
# y_true : vérité terrain de dimension B x 3 x 14
# y_pred : une prédiction de dimension B x 2 x 14 (on ne prédit pas la visibilité)
# B est le nombre d'images considérées (par exemple, pourra être la taille d'un mini-batch)
def custom_mae(y_true, y_pred):
    # Changement de dimension : Bx3x14 -> Bx14x3
    y_true = K.permute_dimensions(y_true, (0, 2, 1))
    # Changement de dimension : Bx14x3 -> (B*14)x3
    y_true = K.reshape(y_true, shape=(-1, 3))
  
    # Changement de dimension : Bx2x14 -> Bx14x2
    y_pred = K.permute_dimensions(y_pred, (0, 2, 1))
    # Changement de dimension : Bx14x2 -> (B*14)x2
    y_pred = K.reshape(y_pred, shape=(-1, 2))
    
    # Détermination de l'indices des joints visibles
    visible = K.greater_equal(y_true[:, 2], 1)  
    indices = K.arange(0, K.shape(y_true)[0])
    indices_visible = indices[visible]
    
    # Sélection des vérité-terrains et prédictions des joints visibles
    y_true_visible = K.gather(y_true[:,0:2], indices_visible)
    y_pred_visible = K.gather(y_pred, indices_visible)
    
    # Calcul de la MAE
    return K.mean(K.abs(y_pred_visible[:,0] - y_true_visible[:,0]) + K.abs(y_pred_visible[:,1] - y_true_visible[:,1]))

# %% [markdown]
# Comme d'habitude, on peut monitorer l'entraînement grâce à la fonction suivante (adaptée à nos fonctions *custom_mse* et *custom_mae* définies juste avant) :

# %%
def plot_training_analysis(history):
  mae = history.history['custom_mae']
  val_mae = history.history['val_custom_mae']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.plot(epochs, mae, 'b', linestyle="--",label='Training MAE')
  plt.plot(epochs, val_mae, 'g', label='Validation MAE')
  plt.title('Training and validation MAE')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'b', linestyle="--",label='Training loss')
  plt.plot(epochs, val_loss,'g', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %% [markdown]
# # A vous de jouer :
#
# Pour tenter de résoudre le problème, vous pouvez suivre les étapes suivantes :
#
# - Simplifier le problème en traitant 10 imagettes (par exemple de dimension $64 \times 64$) et construire un réseau qui surapprend parfaitement (qui diminue la perte jusqu'à quasiment 0)
# - Ajouter des images (~1000) et éventuellement recalibrer votre réseau pour à nouveau, obtenir un sur-apprentissage
# - Commencer à corriger le sur-apprentissage en ajoutant de la régularisation (notamment sur les couches denses)
# - Et enfin, utiliser l'ensemble de la base de données pour diminuer le sur-apprentissage au maximum

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Reshape, Conv2D, MaxPooling2D, Reshape, Flatten, Dropout, Normalization

model = Sequential()


model = Sequential()
model.add(Normalization())
model.add(Conv2D(32, (3, 3), activation="relu", input_shape=(64,64,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(96, (3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(28, activation="relu"))
model.add(Reshape((2,14)))

model.compile(loss=custom_mse,
              optimizer=optimizers.Adam(learning_rate=3e-4),
              metrics=[custom_mae])

history = model.fit(x, y, validation_split=0.1, batch_size=10, epochs=200)
plot_training_analysis(history)
# Out:
# Epoch 1/200
# 90/90 [==============================] - 8s 14ms/step - loss: 1122.5356 - custom_mae: 39.5142 - val_loss: 666.8187 - val_custom_mae: 29.9760
# Epoch 2/200
# 90/90 [==============================] - 1s 6ms/step - loss: 737.1259 - custom_mae: 31.0170 - val_loss: 376.5901 - val_custom_mae: 21.9814
# Epoch 3/200
# 90/90 [==============================] - 1s 7ms/step - loss: 553.4539 - custom_mae: 26.6977 - val_loss: 324.2809 - val_custom_mae: 20.3723
# Epoch 4/200
# 90/90 [==============================] - 1s 6ms/step - loss: 518.1586 - custom_mae: 25.7701 - val_loss: 366.2393 - val_custom_mae: 21.8498
# Epoch 5/200
# 90/90 [==============================] - 1s 6ms/step - loss: 473.4742 - custom_mae: 24.4716 - val_loss: 386.9887 - val_custom_mae: 22.5987
# Epoch 6/200
# 90/90 [==============================] - 1s 7ms/step - loss: 447.2753 - custom_mae: 23.9275 - val_loss: 301.3775 - val_custom_mae: 19.5697
# Epoch 7/200
# 90/90 [==============================] - 1s 6ms/step - loss: 427.5878 - custom_mae: 23.2157 - val_loss: 295.6065 - val_custom_mae: 19.3978
# Epoch 8/200
# 90/90 [==============================] - 1s 6ms/step - loss: 414.8322 - custom_mae: 22.8864 - val_loss: 258.6481 - val_custom_mae: 18.0943
# Epoch 9/200
# 90/90 [==============================] - 1s 6ms/step - loss: 385.6244 - custom_mae: 22.0536 - val_loss: 316.7145 - val_custom_mae: 20.1431
# Epoch 10/200
# 90/90 [==============================] - 1s 7ms/step - loss: 365.6938 - custom_mae: 21.6369 - val_loss: 267.6039 - val_custom_mae: 18.4372
# Epoch 11/200
# 90/90 [==============================] - 1s 7ms/step - loss: 370.4941 - custom_mae: 21.6833 - val_loss: 276.6165 - val_custom_mae: 18.6762
# Epoch 12/200
# 90/90 [==============================] - 1s 7ms/step - loss: 341.0744 - custom_mae: 20.7995 - val_loss: 257.4195 - val_custom_mae: 18.0385
# Epoch 13/200
# 90/90 [==============================] - 1s 6ms/step - loss: 342.0606 - custom_mae: 20.8322 - val_loss: 265.3336 - val_custom_mae: 18.3148
# Epoch 14/200
# 90/90 [==============================] - 1s 7ms/step - loss: 336.2282 - custom_mae: 20.5783 - val_loss: 246.9447 - val_custom_mae: 17.6903
# Epoch 15/200
# 90/90 [==============================] - 1s 7ms/step - loss: 333.9137 - custom_mae: 20.5314 - val_loss: 273.4210 - val_custom_mae: 18.6447
# Epoch 16/200
# 90/90 [==============================] - 1s 7ms/step - loss: 319.4655 - custom_mae: 20.0367 - val_loss: 302.4409 - val_custom_mae: 19.5583
# Epoch 17/200
# 90/90 [==============================] - 1s 7ms/step - loss: 314.0771 - custom_mae: 19.9283 - val_loss: 269.6138 - val_custom_mae: 18.4759
# Epoch 18/200
# 90/90 [==============================] - 1s 8ms/step - loss: 300.5326 - custom_mae: 19.4916 - val_loss: 269.1190 - val_custom_mae: 18.3435
# Epoch 19/200
# 90/90 [==============================] - 1s 8ms/step - loss: 309.5597 - custom_mae: 19.8198 - val_loss: 251.6108 - val_custom_mae: 17.8072
# Epoch 20/200
# 90/90 [==============================] - 1s 9ms/step - loss: 298.9576 - custom_mae: 19.4356 - val_loss: 272.7046 - val_custom_mae: 18.6062
# Epoch 21/200
# 90/90 [==============================] - 1s 7ms/step - loss: 295.9576 - custom_mae: 19.2814 - val_loss: 271.5233 - val_custom_mae: 18.4704
# Epoch 22/200
# 90/90 [==============================] - 1s 6ms/step - loss: 298.2042 - custom_mae: 19.3609 - val_loss: 251.2251 - val_custom_mae: 17.8582
# Epoch 23/200
# 90/90 [==============================] - 1s 6ms/step - loss: 293.7454 - custom_mae: 19.2270 - val_loss: 290.3614 - val_custom_mae: 19.1603
# Epoch 24/200
# 90/90 [==============================] - 1s 7ms/step - loss: 288.4457 - custom_mae: 19.0441 - val_loss: 266.6676 - val_custom_mae: 18.2964
# Epoch 25/200
# 90/90 [==============================] - 1s 6ms/step - loss: 287.2183 - custom_mae: 19.0464 - val_loss: 261.8492 - val_custom_mae: 18.0366
# Epoch 26/200
# 90/90 [==============================] - 1s 7ms/step - loss: 276.9148 - custom_mae: 18.6782 - val_loss: 254.9586 - val_custom_mae: 17.7865
# Epoch 27/200
# 90/90 [==============================] - 1s 6ms/step - loss: 283.4862 - custom_mae: 18.9586 - val_loss: 251.7887 - val_custom_mae: 17.8667
# Epoch 28/200
# 90/90 [==============================] - 1s 7ms/step - loss: 284.0993 - custom_mae: 18.8734 - val_loss: 243.2801 - val_custom_mae: 17.4966
# Epoch 29/200
# 90/90 [==============================] - 1s 7ms/step - loss: 270.0098 - custom_mae: 18.4261 - val_loss: 243.3582 - val_custom_mae: 17.4921
# Epoch 30/200
# 90/90 [==============================] - 1s 6ms/step - loss: 269.2207 - custom_mae: 18.4366 - val_loss: 248.7304 - val_custom_mae: 17.6621
# Epoch 31/200
# 90/90 [==============================] - 1s 6ms/step - loss: 264.5221 - custom_mae: 18.3073 - val_loss: 298.4935 - val_custom_mae: 19.4242
# Epoch 32/200
# 90/90 [==============================] - 1s 6ms/step - loss: 267.1815 - custom_mae: 18.3754 - val_loss: 250.5506 - val_custom_mae: 17.6543
# Epoch 33/200
# 90/90 [==============================] - 1s 6ms/step - loss: 263.1045 - custom_mae: 18.1950 - val_loss: 243.3582 - val_custom_mae: 17.3984
# Epoch 34/200
# 90/90 [==============================] - 1s 6ms/step - loss: 267.5658 - custom_mae: 18.3566 - val_loss: 248.7073 - val_custom_mae: 17.5610
# Epoch 35/200
# 90/90 [==============================] - 1s 6ms/step - loss: 268.5233 - custom_mae: 18.4356 - val_loss: 245.0309 - val_custom_mae: 17.5355
# Epoch 36/200
# 90/90 [==============================] - 1s 7ms/step - loss: 259.3084 - custom_mae: 18.0133 - val_loss: 242.5719 - val_custom_mae: 17.3622
# Epoch 37/200
# 90/90 [==============================] - 1s 7ms/step - loss: 263.5181 - custom_mae: 18.2661 - val_loss: 244.3396 - val_custom_mae: 17.5137
# Epoch 38/200
# 90/90 [==============================] - 1s 8ms/step - loss: 261.7548 - custom_mae: 18.1505 - val_loss: 249.3505 - val_custom_mae: 17.6599
# Epoch 39/200
# 90/90 [==============================] - 1s 9ms/step - loss: 253.1294 - custom_mae: 17.8272 - val_loss: 245.8165 - val_custom_mae: 17.5588
# Epoch 40/200
# 90/90 [==============================] - 1s 8ms/step - loss: 262.7786 - custom_mae: 18.1309 - val_loss: 254.1067 - val_custom_mae: 17.9561
# Epoch 41/200
# 90/90 [==============================] - 1s 7ms/step - loss: 250.7973 - custom_mae: 17.7463 - val_loss: 235.5451 - val_custom_mae: 17.2289
# Epoch 42/200
# 90/90 [==============================] - 1s 7ms/step - loss: 251.2888 - custom_mae: 17.8183 - val_loss: 255.6666 - val_custom_mae: 17.7793
# Epoch 43/200
# 90/90 [==============================] - 1s 6ms/step - loss: 254.7097 - custom_mae: 17.8764 - val_loss: 267.9564 - val_custom_mae: 18.2073
# Epoch 44/200
# 90/90 [==============================] - 1s 6ms/step - loss: 246.6487 - custom_mae: 17.6243 - val_loss: 253.5269 - val_custom_mae: 17.8912
# Epoch 45/200
# 90/90 [==============================] - 1s 6ms/step - loss: 257.2321 - custom_mae: 17.9737 - val_loss: 245.4133 - val_custom_mae: 17.6734
# Epoch 46/200
# 90/90 [==============================] - 1s 6ms/step - loss: 244.1308 - custom_mae: 17.5339 - val_loss: 248.9846 - val_custom_mae: 17.5166
# Epoch 47/200
# 90/90 [==============================] - 1s 6ms/step - loss: 243.6368 - custom_mae: 17.5071 - val_loss: 246.3698 - val_custom_mae: 17.5082
# Epoch 48/200
# 90/90 [==============================] - 1s 7ms/step - loss: 244.3949 - custom_mae: 17.5517 - val_loss: 244.6549 - val_custom_mae: 17.4071
# Epoch 49/200
# 90/90 [==============================] - 1s 9ms/step - loss: 239.1083 - custom_mae: 17.3191 - val_loss: 244.9355 - val_custom_mae: 17.3755
# Epoch 50/200
# 90/90 [==============================] - 1s 9ms/step - loss: 241.0925 - custom_mae: 17.4687 - val_loss: 250.1288 - val_custom_mae: 17.6293
# Epoch 51/200
# 90/90 [==============================] - 1s 7ms/step - loss: 242.9517 - custom_mae: 17.4700 - val_loss: 258.9926 - val_custom_mae: 17.8935
# Epoch 52/200
# 90/90 [==============================] - 1s 6ms/step - loss: 239.8748 - custom_mae: 17.4121 - val_loss: 252.0853 - val_custom_mae: 17.6440
# Epoch 53/200
# 90/90 [==============================] - 1s 6ms/step - loss: 243.0838 - custom_mae: 17.4742 - val_loss: 240.5038 - val_custom_mae: 17.2245
# Epoch 54/200
# 90/90 [==============================] - 1s 6ms/step - loss: 243.9736 - custom_mae: 17.4637 - val_loss: 247.3099 - val_custom_mae: 17.4147
# Epoch 55/200
# 90/90 [==============================] - 1s 7ms/step - loss: 241.5477 - custom_mae: 17.4805 - val_loss: 247.3369 - val_custom_mae: 17.3734
# Epoch 56/200
# 90/90 [==============================] - 1s 6ms/step - loss: 235.2780 - custom_mae: 17.1855 - val_loss: 255.3905 - val_custom_mae: 17.6613
# Epoch 57/200
# 90/90 [==============================] - 1s 8ms/step - loss: 240.2321 - custom_mae: 17.3879 - val_loss: 250.2563 - val_custom_mae: 17.5559
# Epoch 58/200
# 90/90 [==============================] - 1s 9ms/step - loss: 238.9939 - custom_mae: 17.3377 - val_loss: 242.1048 - val_custom_mae: 17.2453
# Epoch 59/200
# 90/90 [==============================] - 1s 9ms/step - loss: 235.4212 - custom_mae: 17.2048 - val_loss: 242.6484 - val_custom_mae: 17.2794
# Epoch 60/200
# 90/90 [==============================] - 1s 8ms/step - loss: 239.2354 - custom_mae: 17.2756 - val_loss: 242.2810 - val_custom_mae: 17.2360
# Epoch 61/200
# 90/90 [==============================] - 1s 7ms/step - loss: 236.4033 - custom_mae: 17.2295 - val_loss: 237.1724 - val_custom_mae: 17.0980
# Epoch 62/200
# 90/90 [==============================] - 1s 6ms/step - loss: 228.3017 - custom_mae: 16.9596 - val_loss: 247.3253 - val_custom_mae: 17.4149
# Epoch 63/200
# 90/90 [==============================] - 1s 7ms/step - loss: 230.2598 - custom_mae: 17.0223 - val_loss: 249.9716 - val_custom_mae: 17.4680
# Epoch 64/200
# 90/90 [==============================] - 1s 6ms/step - loss: 231.9357 - custom_mae: 17.0513 - val_loss: 243.6726 - val_custom_mae: 17.3137
# Epoch 65/200
# 90/90 [==============================] - 1s 6ms/step - loss: 226.2626 - custom_mae: 16.7444 - val_loss: 240.4613 - val_custom_mae: 17.2458
# Epoch 66/200
# 90/90 [==============================] - 1s 6ms/step - loss: 224.8190 - custom_mae: 16.7424 - val_loss: 254.2096 - val_custom_mae: 17.8495
# Epoch 67/200
# 90/90 [==============================] - 1s 7ms/step - loss: 221.8488 - custom_mae: 16.6667 - val_loss: 241.0742 - val_custom_mae: 17.2734
# Epoch 68/200
# 90/90 [==============================] - 1s 6ms/step - loss: 222.5288 - custom_mae: 16.6218 - val_loss: 238.0667 - val_custom_mae: 17.0247
# Epoch 69/200
# 90/90 [==============================] - 1s 7ms/step - loss: 219.1684 - custom_mae: 16.4972 - val_loss: 242.5670 - val_custom_mae: 17.2799
# Epoch 70/200
# 90/90 [==============================] - 1s 7ms/step - loss: 218.6166 - custom_mae: 16.5063 - val_loss: 235.6351 - val_custom_mae: 17.0539
# Epoch 71/200
# 90/90 [==============================] - 1s 6ms/step - loss: 219.9932 - custom_mae: 16.4725 - val_loss: 240.4219 - val_custom_mae: 17.3274
# Epoch 72/200
# 90/90 [==============================] - 1s 7ms/step - loss: 215.7462 - custom_mae: 16.3421 - val_loss: 251.2620 - val_custom_mae: 17.5045
# Epoch 73/200
# 90/90 [==============================] - 1s 6ms/step - loss: 211.5914 - custom_mae: 16.1432 - val_loss: 235.6550 - val_custom_mae: 16.8638
# Epoch 74/200
# 90/90 [==============================] - 1s 6ms/step - loss: 210.7798 - custom_mae: 16.0874 - val_loss: 238.7353 - val_custom_mae: 17.0666
# Epoch 75/200
# 90/90 [==============================] - 1s 6ms/step - loss: 208.7510 - custom_mae: 16.0589 - val_loss: 240.3032 - val_custom_mae: 16.9842
# Epoch 76/200
# 90/90 [==============================] - 1s 6ms/step - loss: 209.5120 - custom_mae: 16.0633 - val_loss: 240.3420 - val_custom_mae: 16.9363
# Epoch 77/200
# 90/90 [==============================] - 1s 8ms/step - loss: 206.3526 - custom_mae: 15.9309 - val_loss: 254.6843 - val_custom_mae: 17.6387
# Epoch 78/200
# 90/90 [==============================] - 1s 9ms/step - loss: 207.7759 - custom_mae: 15.8715 - val_loss: 238.7652 - val_custom_mae: 17.1423
# Epoch 79/200
# 90/90 [==============================] - 1s 9ms/step - loss: 202.2896 - custom_mae: 15.7088 - val_loss: 244.8802 - val_custom_mae: 17.3274
# Epoch 80/200
# 90/90 [==============================] - 1s 7ms/step - loss: 205.4578 - custom_mae: 15.9495 - val_loss: 235.0341 - val_custom_mae: 16.8474
# Epoch 81/200
# 90/90 [==============================] - 1s 6ms/step - loss: 197.5978 - custom_mae: 15.5246 - val_loss: 228.1915 - val_custom_mae: 16.5972
# Epoch 82/200
# 90/90 [==============================] - 1s 6ms/step - loss: 194.4593 - custom_mae: 15.4689 - val_loss: 243.6030 - val_custom_mae: 16.9801
# Epoch 83/200
# 90/90 [==============================] - 1s 7ms/step - loss: 200.5997 - custom_mae: 15.6931 - val_loss: 234.9305 - val_custom_mae: 16.9590
# Epoch 84/200
# 90/90 [==============================] - 1s 6ms/step - loss: 198.4308 - custom_mae: 15.5184 - val_loss: 230.8042 - val_custom_mae: 16.7641
# Epoch 85/200
# 90/90 [==============================] - 1s 6ms/step - loss: 193.7874 - custom_mae: 15.3473 - val_loss: 235.6052 - val_custom_mae: 16.8141
# Epoch 86/200
# 90/90 [==============================] - 1s 7ms/step - loss: 191.0956 - custom_mae: 15.2170 - val_loss: 228.9280 - val_custom_mae: 16.6261
# Epoch 87/200
# 90/90 [==============================] - 1s 6ms/step - loss: 191.6299 - custom_mae: 15.2740 - val_loss: 235.2600 - val_custom_mae: 16.9603
# Epoch 88/200
# 90/90 [==============================] - 1s 6ms/step - loss: 184.0488 - custom_mae: 14.9608 - val_loss: 233.8367 - val_custom_mae: 16.9270
# Epoch 89/200
# 90/90 [==============================] - 1s 7ms/step - loss: 194.9497 - custom_mae: 15.3557 - val_loss: 232.8044 - val_custom_mae: 16.7851
# Epoch 90/200
# 90/90 [==============================] - 1s 6ms/step - loss: 193.2348 - custom_mae: 15.2739 - val_loss: 229.9161 - val_custom_mae: 16.7658
# Epoch 91/200
# 90/90 [==============================] - 1s 6ms/step - loss: 190.0383 - custom_mae: 15.2041 - val_loss: 227.0071 - val_custom_mae: 16.6586
# Epoch 92/200
# 90/90 [==============================] - 1s 7ms/step - loss: 192.7199 - custom_mae: 15.3390 - val_loss: 238.9751 - val_custom_mae: 17.1121
# Epoch 93/200
# 90/90 [==============================] - 1s 7ms/step - loss: 187.4499 - custom_mae: 15.1153 - val_loss: 237.7211 - val_custom_mae: 16.9771
# Epoch 94/200
# 90/90 [==============================] - 1s 7ms/step - loss: 192.0847 - custom_mae: 15.2615 - val_loss: 233.0695 - val_custom_mae: 16.8629
# Epoch 95/200
# 90/90 [==============================] - 1s 7ms/step - loss: 192.9028 - custom_mae: 15.3945 - val_loss: 239.0729 - val_custom_mae: 16.9733
# Epoch 96/200
# 90/90 [==============================] - 1s 7ms/step - loss: 186.7043 - custom_mae: 15.1121 - val_loss: 245.5222 - val_custom_mae: 17.1981
# Epoch 97/200
# 90/90 [==============================] - 1s 9ms/step - loss: 190.1950 - custom_mae: 15.1554 - val_loss: 234.9500 - val_custom_mae: 16.9226
# Epoch 98/200
# 90/90 [==============================] - 1s 9ms/step - loss: 182.0324 - custom_mae: 14.8637 - val_loss: 238.1140 - val_custom_mae: 16.8596
# Epoch 99/200
# 90/90 [==============================] - 1s 9ms/step - loss: 185.4577 - custom_mae: 15.0102 - val_loss: 233.8213 - val_custom_mae: 16.6974
# Epoch 100/200
# 90/90 [==============================] - 1s 6ms/step - loss: 186.4565 - custom_mae: 15.0233 - val_loss: 241.9425 - val_custom_mae: 17.2624
# Epoch 101/200
# 90/90 [==============================] - 1s 6ms/step - loss: 182.9858 - custom_mae: 14.9291 - val_loss: 235.3726 - val_custom_mae: 17.0320
# Epoch 102/200
# 90/90 [==============================] - 1s 7ms/step - loss: 182.8246 - custom_mae: 14.8588 - val_loss: 230.7264 - val_custom_mae: 16.8105
# Epoch 103/200
# 90/90 [==============================] - 1s 7ms/step - loss: 184.3953 - custom_mae: 14.9026 - val_loss: 230.9268 - val_custom_mae: 16.8160
# Epoch 104/200
# 90/90 [==============================] - 1s 6ms/step - loss: 181.6317 - custom_mae: 14.8101 - val_loss: 238.0529 - val_custom_mae: 17.0892
# Epoch 105/200
# 90/90 [==============================] - 1s 7ms/step - loss: 184.4410 - custom_mae: 14.8851 - val_loss: 238.5485 - val_custom_mae: 16.8854
# Epoch 106/200
# 90/90 [==============================] - 1s 6ms/step - loss: 182.6995 - custom_mae: 14.8773 - val_loss: 238.3750 - val_custom_mae: 16.9026
# Epoch 107/200
# 90/90 [==============================] - 1s 7ms/step - loss: 184.4428 - custom_mae: 14.9621 - val_loss: 228.0475 - val_custom_mae: 16.6084
# Epoch 108/200
# 90/90 [==============================] - 1s 7ms/step - loss: 179.3172 - custom_mae: 14.7672 - val_loss: 232.5344 - val_custom_mae: 16.7673
# Epoch 109/200
# 90/90 [==============================] - 1s 6ms/step - loss: 179.2793 - custom_mae: 14.7125 - val_loss: 238.1977 - val_custom_mae: 17.0858
# Epoch 110/200
# 90/90 [==============================] - 1s 7ms/step - loss: 179.8497 - custom_mae: 14.7347 - val_loss: 234.3164 - val_custom_mae: 16.8379
# Epoch 111/200
# 90/90 [==============================] - 1s 7ms/step - loss: 183.4724 - custom_mae: 14.8869 - val_loss: 237.4240 - val_custom_mae: 17.1291
# Epoch 112/200
# 90/90 [==============================] - 1s 7ms/step - loss: 178.3647 - custom_mae: 14.6588 - val_loss: 233.7680 - val_custom_mae: 16.8662
# Epoch 113/200
# 90/90 [==============================] - 1s 6ms/step - loss: 176.1687 - custom_mae: 14.6073 - val_loss: 235.9111 - val_custom_mae: 16.9229
# Epoch 114/200
# 90/90 [==============================] - 1s 7ms/step - loss: 176.3844 - custom_mae: 14.5889 - val_loss: 234.6036 - val_custom_mae: 16.7599
# Epoch 115/200
# 90/90 [==============================] - 1s 7ms/step - loss: 177.3142 - custom_mae: 14.6147 - val_loss: 236.0535 - val_custom_mae: 16.8860
# Epoch 116/200
# 90/90 [==============================] - 1s 7ms/step - loss: 175.2149 - custom_mae: 14.5522 - val_loss: 241.0871 - val_custom_mae: 17.1270
# Epoch 117/200
# 90/90 [==============================] - 1s 9ms/step - loss: 178.2875 - custom_mae: 14.7151 - val_loss: 232.5847 - val_custom_mae: 16.7748
# Epoch 118/200
# 90/90 [==============================] - 1s 9ms/step - loss: 177.1590 - custom_mae: 14.6356 - val_loss: 232.7647 - val_custom_mae: 16.8472
# Epoch 119/200
# 90/90 [==============================] - 1s 8ms/step - loss: 178.7005 - custom_mae: 14.7422 - val_loss: 245.6427 - val_custom_mae: 17.0000
# Epoch 120/200
# 90/90 [==============================] - 1s 6ms/step - loss: 179.1749 - custom_mae: 14.7182 - val_loss: 233.8942 - val_custom_mae: 16.7352
# Epoch 121/200
# 90/90 [==============================] - 1s 7ms/step - loss: 179.7154 - custom_mae: 14.7494 - val_loss: 244.0029 - val_custom_mae: 17.1551
# Epoch 122/200
# 90/90 [==============================] - 1s 6ms/step - loss: 175.7508 - custom_mae: 14.5958 - val_loss: 236.7823 - val_custom_mae: 17.0100
# Epoch 123/200
# 90/90 [==============================] - 1s 6ms/step - loss: 175.6265 - custom_mae: 14.5596 - val_loss: 241.4756 - val_custom_mae: 17.0819
# Epoch 124/200
# 90/90 [==============================] - 1s 6ms/step - loss: 177.4966 - custom_mae: 14.5896 - val_loss: 242.0481 - val_custom_mae: 17.1937
# Epoch 125/200
# 90/90 [==============================] - 1s 7ms/step - loss: 174.6405 - custom_mae: 14.5188 - val_loss: 249.7776 - val_custom_mae: 17.4297
# Epoch 126/200
# 90/90 [==============================] - 1s 7ms/step - loss: 175.9676 - custom_mae: 14.5823 - val_loss: 230.7549 - val_custom_mae: 16.7149
# Epoch 127/200
# 90/90 [==============================] - 1s 6ms/step - loss: 171.3862 - custom_mae: 14.4555 - val_loss: 240.5733 - val_custom_mae: 17.1238
# Epoch 128/200
# 90/90 [==============================] - 1s 6ms/step - loss: 169.1002 - custom_mae: 14.2920 - val_loss: 228.7608 - val_custom_mae: 16.5671
# Epoch 129/200
# 90/90 [==============================] - 1s 7ms/step - loss: 170.8767 - custom_mae: 14.3888 - val_loss: 237.9712 - val_custom_mae: 16.8622
# Epoch 130/200
# 90/90 [==============================] - 1s 6ms/step - loss: 171.0589 - custom_mae: 14.3596 - val_loss: 235.5637 - val_custom_mae: 16.9098
# Epoch 131/200
# 90/90 [==============================] - 1s 7ms/step - loss: 172.9333 - custom_mae: 14.4924 - val_loss: 235.8649 - val_custom_mae: 16.9915
# Epoch 132/200
# 90/90 [==============================] - 1s 7ms/step - loss: 169.1318 - custom_mae: 14.3812 - val_loss: 239.5649 - val_custom_mae: 17.1655
# Epoch 133/200
# 90/90 [==============================] - 1s 6ms/step - loss: 168.7200 - custom_mae: 14.2243 - val_loss: 235.7678 - val_custom_mae: 16.7981
# Epoch 134/200
# 90/90 [==============================] - 1s 7ms/step - loss: 170.3175 - custom_mae: 14.2778 - val_loss: 240.4025 - val_custom_mae: 17.1928
# Epoch 135/200
# 90/90 [==============================] - 1s 6ms/step - loss: 171.7757 - custom_mae: 14.3538 - val_loss: 244.0259 - val_custom_mae: 17.2593
# Epoch 136/200
# 90/90 [==============================] - 1s 8ms/step - loss: 169.1872 - custom_mae: 14.3067 - val_loss: 241.1801 - val_custom_mae: 17.0738
# Epoch 137/200
# 90/90 [==============================] - 1s 8ms/step - loss: 174.3823 - custom_mae: 14.4400 - val_loss: 235.0775 - val_custom_mae: 16.9625
# Epoch 138/200
# 90/90 [==============================] - 1s 9ms/step - loss: 171.5101 - custom_mae: 14.3596 - val_loss: 243.3211 - val_custom_mae: 17.0801
# Epoch 139/200
# 90/90 [==============================] - 1s 8ms/step - loss: 166.5151 - custom_mae: 14.1430 - val_loss: 238.4349 - val_custom_mae: 16.9783
# Epoch 140/200
# 90/90 [==============================] - 1s 7ms/step - loss: 175.9382 - custom_mae: 14.5626 - val_loss: 251.8395 - val_custom_mae: 17.4547
# Epoch 141/200
# 90/90 [==============================] - 1s 6ms/step - loss: 172.6052 - custom_mae: 14.4215 - val_loss: 246.0280 - val_custom_mae: 17.2653
# Epoch 142/200
# 90/90 [==============================] - 1s 6ms/step - loss: 167.0367 - custom_mae: 14.2522 - val_loss: 243.8123 - val_custom_mae: 17.1651
# Epoch 143/200
# 90/90 [==============================] - 1s 6ms/step - loss: 167.8872 - custom_mae: 14.1784 - val_loss: 232.5673 - val_custom_mae: 16.7904
# Epoch 144/200
# 90/90 [==============================] - 1s 6ms/step - loss: 166.3573 - custom_mae: 14.1414 - val_loss: 235.6361 - val_custom_mae: 16.8953
# Epoch 145/200
# 90/90 [==============================] - 1s 6ms/step - loss: 169.1613 - custom_mae: 14.2763 - val_loss: 238.9458 - val_custom_mae: 17.0526
# Epoch 146/200
# 90/90 [==============================] - 1s 6ms/step - loss: 171.4978 - custom_mae: 14.3853 - val_loss: 237.8783 - val_custom_mae: 17.0208
# Epoch 147/200
# 90/90 [==============================] - 1s 7ms/step - loss: 166.1377 - custom_mae: 14.1855 - val_loss: 232.4003 - val_custom_mae: 16.8011
# Epoch 148/200
# 90/90 [==============================] - 1s 6ms/step - loss: 162.5839 - custom_mae: 13.9729 - val_loss: 230.7566 - val_custom_mae: 16.7007
# Epoch 149/200
# 90/90 [==============================] - 1s 6ms/step - loss: 158.2791 - custom_mae: 13.8079 - val_loss: 239.1219 - val_custom_mae: 17.0388
# Epoch 150/200
# 90/90 [==============================] - 1s 6ms/step - loss: 159.1640 - custom_mae: 13.8712 - val_loss: 240.7235 - val_custom_mae: 17.1199
# Epoch 151/200
# 90/90 [==============================] - 1s 7ms/step - loss: 159.8501 - custom_mae: 13.8029 - val_loss: 244.6583 - val_custom_mae: 17.2087
# Epoch 152/200
# 90/90 [==============================] - 1s 7ms/step - loss: 160.5857 - custom_mae: 13.8773 - val_loss: 241.6465 - val_custom_mae: 17.1217
# Epoch 153/200
# 90/90 [==============================] - 1s 7ms/step - loss: 155.7514 - custom_mae: 13.7354 - val_loss: 243.0222 - val_custom_mae: 17.1572
# Epoch 154/200
# 90/90 [==============================] - 1s 7ms/step - loss: 155.4561 - custom_mae: 13.6925 - val_loss: 243.1178 - val_custom_mae: 17.1819
# Epoch 155/200
# 90/90 [==============================] - 1s 7ms/step - loss: 151.1279 - custom_mae: 13.5022 - val_loss: 245.0612 - val_custom_mae: 17.2440
# Epoch 156/200
# 90/90 [==============================] - 1s 9ms/step - loss: 151.7518 - custom_mae: 13.4669 - val_loss: 245.3040 - val_custom_mae: 17.2616
# Epoch 157/200
# 90/90 [==============================] - 1s 9ms/step - loss: 156.7020 - custom_mae: 13.7345 - val_loss: 246.0584 - val_custom_mae: 17.3200
# Epoch 158/200
# 90/90 [==============================] - 1s 9ms/step - loss: 149.3417 - custom_mae: 13.4198 - val_loss: 250.0755 - val_custom_mae: 17.3893
# Epoch 159/200
# 90/90 [==============================] - 1s 7ms/step - loss: 149.8249 - custom_mae: 13.4424 - val_loss: 245.4334 - val_custom_mae: 17.2366
# Epoch 160/200
# 90/90 [==============================] - 1s 7ms/step - loss: 150.6267 - custom_mae: 13.4437 - val_loss: 241.8247 - val_custom_mae: 17.1111
# Epoch 161/200
# 90/90 [==============================] - 1s 6ms/step - loss: 149.4520 - custom_mae: 13.4267 - val_loss: 255.8359 - val_custom_mae: 17.6139
# Epoch 162/200
# 90/90 [==============================] - 1s 6ms/step - loss: 145.9674 - custom_mae: 13.2641 - val_loss: 252.2051 - val_custom_mae: 17.4830
# Epoch 163/200
# 90/90 [==============================] - 1s 6ms/step - loss: 144.0067 - custom_mae: 13.1191 - val_loss: 249.4352 - val_custom_mae: 17.4620
# Epoch 164/200
# 90/90 [==============================] - 1s 7ms/step - loss: 149.3495 - custom_mae: 13.3692 - val_loss: 244.1908 - val_custom_mae: 17.1618
# Epoch 165/200
# 90/90 [==============================] - 1s 6ms/step - loss: 145.6024 - custom_mae: 13.2475 - val_loss: 243.1989 - val_custom_mae: 17.3196
# Epoch 166/200
# 90/90 [==============================] - 1s 6ms/step - loss: 145.1439 - custom_mae: 13.1638 - val_loss: 245.6812 - val_custom_mae: 17.1865
# Epoch 167/200
# 90/90 [==============================] - 1s 7ms/step - loss: 143.4936 - custom_mae: 13.0691 - val_loss: 244.8652 - val_custom_mae: 17.1120
# Epoch 168/200
# 90/90 [==============================] - 1s 7ms/step - loss: 147.2180 - custom_mae: 13.2923 - val_loss: 245.1799 - val_custom_mae: 17.0831
# Epoch 169/200
# 90/90 [==============================] - 1s 7ms/step - loss: 142.3344 - custom_mae: 13.0703 - val_loss: 240.4710 - val_custom_mae: 16.9732
# Epoch 170/200
# 90/90 [==============================] - 1s 6ms/step - loss: 144.7513 - custom_mae: 13.2474 - val_loss: 246.8498 - val_custom_mae: 17.2244
# Epoch 171/200
# 90/90 [==============================] - 1s 6ms/step - loss: 140.6409 - custom_mae: 12.9724 - val_loss: 242.5567 - val_custom_mae: 17.1504
# Epoch 172/200
# 90/90 [==============================] - 1s 6ms/step - loss: 144.2397 - custom_mae: 13.1381 - val_loss: 246.6720 - val_custom_mae: 17.2882
# Epoch 173/200
# 90/90 [==============================] - 1s 6ms/step - loss: 143.9829 - custom_mae: 13.1716 - val_loss: 246.8900 - val_custom_mae: 17.2908
# Epoch 174/200
# 90/90 [==============================] - 1s 6ms/step - loss: 143.2099 - custom_mae: 13.0226 - val_loss: 249.7751 - val_custom_mae: 17.2666
# Epoch 175/200
# 90/90 [==============================] - 1s 6ms/step - loss: 140.7802 - custom_mae: 12.9391 - val_loss: 242.4548 - val_custom_mae: 17.0525
# Epoch 176/200
# 90/90 [==============================] - 1s 9ms/step - loss: 137.9050 - custom_mae: 12.8504 - val_loss: 243.3959 - val_custom_mae: 17.2171
# Epoch 177/200
# 90/90 [==============================] - 1s 8ms/step - loss: 139.3869 - custom_mae: 12.9260 - val_loss: 244.0075 - val_custom_mae: 17.0403
# Epoch 178/200
# 90/90 [==============================] - 1s 9ms/step - loss: 138.5579 - custom_mae: 12.8951 - val_loss: 251.9444 - val_custom_mae: 17.5158
# Epoch 179/200
# 90/90 [==============================] - 1s 7ms/step - loss: 139.8220 - custom_mae: 12.9208 - val_loss: 247.4936 - val_custom_mae: 17.2514
# Epoch 180/200
# 90/90 [==============================] - 1s 6ms/step - loss: 138.8661 - custom_mae: 12.9014 - val_loss: 245.3192 - val_custom_mae: 17.2117
# Epoch 181/200
# 90/90 [==============================] - 1s 6ms/step - loss: 137.9826 - custom_mae: 12.8004 - val_loss: 240.2810 - val_custom_mae: 17.0201
# Epoch 182/200
# 90/90 [==============================] - 1s 6ms/step - loss: 137.2699 - custom_mae: 12.8254 - val_loss: 243.9402 - val_custom_mae: 17.2164
# Epoch 183/200
# 90/90 [==============================] - 1s 6ms/step - loss: 135.5848 - custom_mae: 12.6739 - val_loss: 248.5055 - val_custom_mae: 17.3056
# Epoch 184/200
# 90/90 [==============================] - 1s 6ms/step - loss: 134.5753 - custom_mae: 12.6729 - val_loss: 243.9778 - val_custom_mae: 17.0557
# Epoch 185/200
# 90/90 [==============================] - 1s 7ms/step - loss: 136.6406 - custom_mae: 12.7548 - val_loss: 248.3877 - val_custom_mae: 17.4087
# Epoch 186/200
# 90/90 [==============================] - 1s 6ms/step - loss: 139.8837 - custom_mae: 12.8712 - val_loss: 238.4626 - val_custom_mae: 17.0786
# Epoch 187/200
# 90/90 [==============================] - 1s 7ms/step - loss: 138.9571 - custom_mae: 12.8646 - val_loss: 245.5165 - val_custom_mae: 17.1650
# Epoch 188/200
# 90/90 [==============================] - 1s 6ms/step - loss: 135.1741 - custom_mae: 12.6785 - val_loss: 242.3793 - val_custom_mae: 17.1212
# Epoch 189/200
# 90/90 [==============================] - 1s 7ms/step - loss: 140.2106 - custom_mae: 12.9565 - val_loss: 235.3201 - val_custom_mae: 16.8340
# Epoch 190/200
# 90/90 [==============================] - 1s 7ms/step - loss: 136.7597 - custom_mae: 12.7626 - val_loss: 234.9245 - val_custom_mae: 16.8636
# Epoch 191/200
# 90/90 [==============================] - 1s 7ms/step - loss: 139.1197 - custom_mae: 12.8595 - val_loss: 253.5679 - val_custom_mae: 17.5764
# Epoch 192/200
# 90/90 [==============================] - 1s 7ms/step - loss: 145.7589 - custom_mae: 13.1201 - val_loss: 238.4164 - val_custom_mae: 17.0987
# Epoch 193/200
# 90/90 [==============================] - 1s 6ms/step - loss: 137.9954 - custom_mae: 12.8193 - val_loss: 236.2179 - val_custom_mae: 16.9064
# Epoch 194/200
# 90/90 [==============================] - 1s 7ms/step - loss: 136.2421 - custom_mae: 12.7026 - val_loss: 241.3568 - val_custom_mae: 16.9889
# Epoch 195/200
# 90/90 [==============================] - 1s 6ms/step - loss: 134.3840 - custom_mae: 12.6601 - val_loss: 238.0990 - val_custom_mae: 16.9698
# Epoch 196/200
# 90/90 [==============================] - 1s 8ms/step - loss: 136.5500 - custom_mae: 12.7550 - val_loss: 243.0754 - val_custom_mae: 16.9312
# Epoch 197/200
# 90/90 [==============================] - 1s 8ms/step - loss: 129.8812 - custom_mae: 12.4134 - val_loss: 244.2440 - val_custom_mae: 17.0049
# Epoch 198/200
# 90/90 [==============================] - 1s 8ms/step - loss: 136.3997 - custom_mae: 12.7311 - val_loss: 238.6830 - val_custom_mae: 16.9475
# Epoch 199/200
# 90/90 [==============================] - 1s 7ms/step - loss: 135.4778 - custom_mae: 12.6946 - val_loss: 236.9984 - val_custom_mae: 16.9150
# Epoch 200/200
# 90/90 [==============================] - 1s 7ms/step - loss: 133.8458 - custom_mae: 12.6627 - val_loss: 244.2190 - val_custom_mae: 17.1978
